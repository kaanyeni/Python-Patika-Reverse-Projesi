# %%
def reverse_f (x):
    x.reverse()
    for i in x:
            i.reverse()
    return x

input =  [[1, 2], [3, 4], [5, 6, 7]]
output = []
output = reverse_f(input)
print (output)
# Out:
# [[7, 6, 5], [4, 3], [2, 1]]
